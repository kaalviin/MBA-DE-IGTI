# %%
import findspark
findspark.init()

# %%
from pyspark.context import SparkContext
from pyspark.sql import SparkSession

# %%
from pyspark.sql.types import *
from pyspark.sql.functions import *
from pyspark.sql import functions as FUNC

# %%
data_path = ("C:/Bootcamp/Datasets/CSV/Microdados_Educação_Superior_2019/dados/")

# %%
spark = (
    SparkSession
    .builder
    .config("spark.driver.memory", '8g')
    .enableHiveSupport()
    .getOrCreate()
)

# %%
df_aluno_2019_sup = spark.read.csv("C:/Bootcamp/Datasets/CSV/Microdados_Educação_Superior_2019/dados/SUP_ALUNO_2019.csv", header=True, sep='|')

# %%
df_aluno_2019_sup.limit(10).toPandas()
# Out:
#   NU_ANO_CENSO CO_IES TP_CATEGORIA_ADMINISTRATIVA TP_ORGANIZACAO_ACADEMICA  \
# 0         2019      1                           1                        1
# 1         2019      1                           1                        1
# 2         2019      1                           1                        1
# 3         2019      1                           1                        1
# 4         2019      1                           1                        1
# 5         2019      1                           1                        1
# 6         2019      1                           1                        1
# 7         2019      1                           1                        1
# 8         2019      1                           1                        1
# 9         2019      1                           1                        1
#
#   CO_CURSO CO_CURSO_POLO TP_TURNO TP_GRAU_ACADEMICO TP_MODALIDADE_ENSINO  \
# ...

# %%
df_aluno_2019_sup.columns
# Out:
# ['NU_ANO_CENSO',
#  'CO_IES',
#  'TP_CATEGORIA_ADMINISTRATIVA',
#  'TP_ORGANIZACAO_ACADEMICA',
#  'CO_CURSO',
#  'CO_CURSO_POLO',
#  'TP_TURNO',
#  'TP_GRAU_ACADEMICO',
#  'TP_MODALIDADE_ENSINO',
#  'TP_NIVEL_ACADEMICO',
#  'CO_CINE_ROTULO',
#  'ID_ALUNO',
#  'CO_ALUNO_CURSO',
#  'CO_ALUNO_CURSO_ORIGEM',
#  'TP_COR_RACA',
#  'TP_SEXO',
#  'NU_ANO_NASCIMENTO',
#  'NU_MES_NASCIMENTO',
#  'NU_DIA_NASCIMENTO',
#  'NU_IDADE',
#  'TP_NACIONALIDADE',
#  'CO_PAIS_ORIGEM',
#  'CO_UF_NASCIMENTO',
#  'CO_MUNICIPIO_NASCIMENTO',
#  'IN_DEFICIENCIA',
#  'IN_DEFICIENCIA_AUDITIVA',
#  'IN_DEFICIENCIA_FISICA',
#  'IN_DEFICIENCIA_INTELECTUAL',
#  'IN_DEFICIENCIA_MULTIPLA',
#  'IN_DEFICIENCIA_SURDEZ',
#  'IN_DEFICIENCIA_SURDOCEGUEIRA',
#  'IN_DEFICIENCIA_BAIXA_VISAO',
#  'IN_DEFICIENCIA_CEGUEIRA',
#  'IN_DEFICIENCIA_SUPERDOTACAO',
#  'IN_TGD_AUTISMO',
#  'IN_TGD_SINDROME_ASPERGER',
#  'IN_TGD_SINDROME_RETT',
#  'IN_TGD_TRANSTOR_DESINTEGRATIVO',
#  'TP_SITUACAO',
#  'QT_CARGA_HORARIA_TOTAL',
# ...

# %%
#QUESTÃO 1 PRIMEIRO DATAFRAME SÓ DE CENSO_2019, DEPOIS AGROUPAR E CONTAR PLEA TP_COR_RACA#

# %%
(
df_aluno_2019_sup_year_2019.groupby("TP_COR_RACA")
                           .count()
                           .orderBy(col("count").desc())
                           .limit(20).toPandas()
)
# Out:
#   TP_COR_RACA    count
# 0           1  5197015
# 1           3  3741949
# 2           0  2227513
# 3           2   872733
# 4           4   208408
# 5           5    80652
# 6           9    22562

# %%
df_aluno_2019_sup_year_2019 = df_aluno_2019_sup.filter(col('NU_ANO_CENSO') == 2019)
df_aluno_2019_sup_year_2019.limit(10).toPandas()
# Out:
#   NU_ANO_CENSO CO_IES TP_CATEGORIA_ADMINISTRATIVA TP_ORGANIZACAO_ACADEMICA  \
# 0         2019      1                           1                        1
# 1         2019      1                           1                        1
# 2         2019      1                           1                        1
# 3         2019      1                           1                        1
# 4         2019      1                           1                        1
# 5         2019      1                           1                        1
# 6         2019      1                           1                        1
# 7         2019      1                           1                        1
# 8         2019      1                           1                        1
# 9         2019      1                           1                        1
#
#   CO_CURSO CO_CURSO_POLO TP_TURNO TP_GRAU_ACADEMICO TP_MODALIDADE_ENSINO  \
# ...

# %%
df_aluno_ies = spark.read.csv("/C:/Users/rodri/Desktop/engenharia de dados/desafio_final/Microdados_Educação_Superior_2019/dados/SUP_IES_2019.csv", header=True, sep='|')

# %%
df_aluno_ies.limit(10).toPandas()
# Out:
#   NU_ANO_CENSO CO_IES                                      NO_IES    SG_IES  \
# 0         2019      1         UNIVERSIDADE FEDERAL DE MATO GROSSO      UFMT
# 1         2019      2                    UNIVERSIDADE DE BRAS�LIA       UNB
# 2         2019      3             UNIVERSIDADE FEDERAL DE SERGIPE       UFS
# 3         2019      4            UNIVERSIDADE FEDERAL DO AMAZONAS      UFAM
# 4         2019      6          UNIVERSIDADE FEDERAL DE OURO PRETO      UFOP
# 5         2019     10  PONTIF�CIA UNIVERSIDADE CAT�LICA DO PARAN�     PUCPR
# 6         2019     11         UNIVERSIDADE CAT�LICA DE PERNAMBUCO    UNICAP
# 7         2019     13               UNIVERSIDADE DE CAXIAS DO SUL       UCS
# 8         2019     14       UNIVERSIDADE DO VALE DO RIO DOS SINOS  UNISINOS
# 9         2019     18            UNIVERSIDADE CAT�LICA DE PELOTAS     UCPEL
#
#   CO_MANTENEDORA                                 NO_MANTENEDORA  \
# 0              1   FUNDACAO UNIVERSIDADE FEDERAL DE MATO GROSSO
# ...

# %%
df_curso_2019 = spark.read.csv("/C:/Users/rodri/Desktop/engenharia de dados/desafio_final/Microdados_Educação_Superior_2019/dados/SUP_CURSO_2019.csv", header=True, sep='|')

# %%
df_curso_2019.limit(10).toPandas()
# Out:
#   NU_ANO_CENSO CO_IES TP_CATEGORIA_ADMINISTRATIVA TP_ORGANIZACAO_ACADEMICA  \
# 0         2019      1                           1                        1
# 1         2019      1                           1                        1
# 2         2019      1                           1                        1
# 3         2019      1                           1                        1
# 4         2019      1                           1                        1
# 5         2019      1                           1                        1
# 6         2019      1                           1                        1
# 7         2019      1                           1                        1
# 8         2019      1                           1                        1
# 9         2019      1                           1                        1
#
#   CO_LOCAL_OFERTA CO_UF CO_MUNICIPIO IN_CAPITAL CO_CURSO  \
# 0          105340    51      5103403          1        1
# ...

# %%
#QUESTÃO 2 coluna CO_UF_NASCIMENTO = 35 E SEXO FEMININO E SEXO DO ALUNO TP_SEXO

# %%
df_aluno_2019_sexo_F = df_aluno_2019_sup.filter(col('TP_SEXO') == 1)
df_aluno_2019_sexo_F.limit(10).toPandas()
# Out:
#   NU_ANO_CENSO CO_IES TP_CATEGORIA_ADMINISTRATIVA TP_ORGANIZACAO_ACADEMICA  \
# 0         2019      1                           1                        1
# 1         2019      1                           1                        1
# 2         2019      1                           1                        1
# 3         2019      1                           1                        1
# 4         2019      1                           1                        1
# 5         2019      1                           1                        1
# 6         2019      1                           1                        1
# 7         2019      1                           1                        1
# 8         2019      1                           1                        1
# 9         2019      1                           1                        1
#
#   CO_CURSO CO_CURSO_POLO TP_TURNO TP_GRAU_ACADEMICO TP_MODALIDADE_ENSINO  \
# ...

# %%
(
df_aluno_2019_sexo_F.groupby("CO_UF_NASCIMENTO")
                           .count()
                           .orderBy(col("count").desc())
                           .limit(20).toPandas()
)
# Out:
#    CO_UF_NASCIMENTO    count
# 0              None  1965496
# 1                35  1004194
# 2                31   557883
# 3                33   504518
# 4                41   336731
# 5                29   326461
# 6                43   308656
# 7                42   207662
# 8                23   191898
# 9                26   167626
# 10               15   154817
# 11               21   153806
# 12               52   150252
# 13               32    97418
# 14               53    94754
# 15               51    93799
# 16               13    89340
# 17               50    74316
# 18               25    72879
# 19               27    65241

# %%
# TP_SEXO 1 entraram CO_UF_NASCIMENTO 43 entraram por cotas IN_RESERVA_ETNICO 1#

# %%
df_questao_3 = df_aluno_2019_sexo_F.filter(col("IN_RESERVA_ETNICO") == 1)
df_questao_3.limit(10).toPandas()
# Out:
#   NU_ANO_CENSO CO_IES TP_CATEGORIA_ADMINISTRATIVA TP_ORGANIZACAO_ACADEMICA  \
# 0         2019      1                           1                        1
# 1         2019      1                           1                        1
# 2         2019      1                           1                        1
# 3         2019      1                           1                        1
# 4         2019      1                           1                        1
# 5         2019      1                           1                        1
# 6         2019      1                           1                        1
# 7         2019      1                           1                        1
# 8         2019      1                           1                        1
# 9         2019      1                           1                        1
#
#   CO_CURSO CO_CURSO_POLO TP_TURNO TP_GRAU_ACADEMICO TP_MODALIDADE_ENSINO  \
# ...

# %%
(
df_questao_3.groupby("CO_UF_NASCIMENTO")
                           .count()
                           .orderBy(col("count").desc())
                           .limit(20).toPandas()
)
# Out:
#    CO_UF_NASCIMENTO  count
# 0              None  57368
# 1                31  15642
# 2                33  14218
# 3                29  13115
# 4                35  10738
# 5                26   8392
# 6                15   7309
# 7                21   6612
# 8                52   5337
# 9                13   5042
# 10               23   4332
# 11               28   4254
# 12               25   2680
# 13               43   2560
# 14               50   2454
# 15               41   2372
# 16               32   2312
# 17               51   1998
# 18               22   1718
# 19               11   1541

# %%
#questao 4 CO_UF_NASCIMENTO MAX  NU_ANO_INGRESSO 2019

# %%
(
df_aluno_2019_sup.groupby("CO_UF_NASCIMENTO")
                    .count()
                    .orderBy(col("count").desc())
                    .limit(20).toPandas()
)
# Out:
#    CO_UF_NASCIMENTO    count
# 0              None  3448606
# 1                35  1865517
# 2                31   982388
# 3                33   922358
# 4                41   606625
# 5                29   552495
# 6                43   543635
# 7                42   368076
# 8                23   349491
# 9                26   307200
# 10               15   274400
# 11               21   266418
# 12               52   265375
# 13               53   176734
# 14               32   175908
# 15               13   164017
# 16               51   161998
# 17               50   132247
# 18               25   132006
# 19               27   112669

# %%
# 6 CO_UF_NASCIMENTO média de idades NU_IDADE

# %%
(
df_aluno_2019_sup.groupby("CO_UF_NASCIMENTO")
                           .agg(FUNC.mean("NU_IDADE").alias('mean_NU_IDADE'))
                           .orderBy(col("mean_NU_IDADE").desc())
                           .limit(20).toPandas()
)
# Out:
#    CO_UF_NASCIMENTO  mean_NU_IDADE
# 0                33      29.046068
# 1                43      28.723342
# 2              None      28.456489
# 3                29      28.442417
# 4                27      28.322192
# 5                15      28.089286
# 6                21      28.027750
# 7                50      28.020159
# 8                22      27.819218
# 9                26      27.762812
# 10               13      27.757970
# 11               25      27.592625
# 12               31      27.590453
# 13               16      27.517055
# 14               24      27.505395
# 15               23      27.483460
# 16               35      27.386045
# 17               14      27.318433
# 18               12      27.297365
# 19               53      27.272155

# %%
# 5 questão CO_UF_NASCIMENTO MENOR NUMERO DE IN_DEFICIENCIA_CEGUEIRA#

# %%
df_questao_5 = df_aluno_2019_sup.filter(col("IN_DEFICIENCIA_CEGUEIRA") == 1)
df_questao_5.limit(10).toPandas()
# Out:
#   NU_ANO_CENSO CO_IES TP_CATEGORIA_ADMINISTRATIVA TP_ORGANIZACAO_ACADEMICA  \
# 0         2019      1                           1                        1
# 1         2019      1                           1                        1
# 2         2019      1                           1                        1
# 3         2019      1                           1                        1
# 4         2019      1                           1                        1
# 5         2019      1                           1                        1
# 6         2019      1                           1                        1
# 7         2019      1                           1                        1
# 8         2019      1                           1                        1
# 9         2019      1                           1                        1
#
#   CO_CURSO CO_CURSO_POLO TP_TURNO TP_GRAU_ACADEMICO TP_MODALIDADE_ENSINO  \
# ...

# %%
(
df_questao_5.groupby("CO_UF_NASCIMENTO")
                           .count()
                           .orderBy(col("count").asc())
                           .limit(20).toPandas()
)
# Out:
#    CO_UF_NASCIMENTO  count
# 0                16      4
# 1                14      7
# 2                12      8
# 3                27     12
# 4                13     22
# 5                17     24
# 6                28     24
# 7                22     27
# 8                24     31
# 9                53     34
# 10               11     35
# 11               32     35
# 12               50     37
# 13               52     40
# 14               51     41
# 15               25     59
# 16               23     70
# 17               43     99
# 18               21    114
# 19               15    116

# %%
# 7 CO_UF_NASCIMENTO segundo maior com aluno com IN_BOLSA_PESQUISA#

# %%
df_questao_7 = df_aluno_2019_sup.filter(col("IN_BOLSA_PESQUISA") == 1)
df_questao_7.limit(10).toPandas()
# Out:
#   NU_ANO_CENSO CO_IES TP_CATEGORIA_ADMINISTRATIVA TP_ORGANIZACAO_ACADEMICA  \
# 0         2019      1                           1                        1
# 1         2019      1                           1                        1
# 2         2019      1                           1                        1
# 3         2019      1                           1                        1
# 4         2019      1                           1                        1
# 5         2019      1                           1                        1
# 6         2019      1                           1                        1
# 7         2019      1                           1                        1
# 8         2019      1                           1                        1
# 9         2019      1                           1                        1
#
#   CO_CURSO CO_CURSO_POLO TP_TURNO TP_GRAU_ACADEMICO TP_MODALIDADE_ENSINO  \
# ...

# %%
(
df_questao_7.groupby("CO_UF_NASCIMENTO")
                           .count()
                           .orderBy(col("count").desc())
                           .limit(20).toPandas()
)
# Out:
#    CO_UF_NASCIMENTO  count
# 0              None  32536
# 1                35   9807
# 2                29   7194
# 3                31   6947
# 4                41   5511
# 5                43   5010
# 6                33   4108
# 7                42   2687
# 8                26   2245
# 9                52   2100
# 10               15   2036
# 11               51   1997
# 12               21   1753
# 13               25   1307
# 14               32   1152
# 15               13   1004
# 16               28    966
# 17               23    826
# 18               22    776
# 19               53    705

# %%
# 8 TP_SEXO igual 1 TP_COR_RACA 2#

# %%
df_questao_8 = df_aluno_2019_sup.filter(col('TP_SEXO') == 1)
df_questao_8.limit(10).toPandas()
# Out:
#   NU_ANO_CENSO CO_IES TP_CATEGORIA_ADMINISTRATIVA TP_ORGANIZACAO_ACADEMICA  \
# 0         2019      1                           1                        1
# 1         2019      1                           1                        1
# 2         2019      1                           1                        1
# 3         2019      1                           1                        1
# 4         2019      1                           1                        1
# 5         2019      1                           1                        1
# 6         2019      1                           1                        1
# 7         2019      1                           1                        1
# 8         2019      1                           1                        1
# 9         2019      1                           1                        1
#
#   CO_CURSO CO_CURSO_POLO TP_TURNO TP_GRAU_ACADEMICO TP_MODALIDADE_ENSINO  \
# ...

# %%
(
df_questao_8.groupby("TP_COR_RACA")
                    .count()
                    .orderBy(col("count").desc())
                    .limit(20).toPandas()
)
# Out:
#   TP_COR_RACA    count
# 0           1  2894940
# 1           3  2128508
# 2           0  1256535
# 3           2   467573
# 4           4   126040
# 5           5    43874
# 6           9    11013

# %%
#9 CO_UF_NASCIMENTO com o segundo maior numero de TP_SEXO 2, ARQUIVO SUP_DOCENTE

# %%
df_sup_docente = spark.read.csv("/C:/Users/rodri/Desktop/engenharia de dados/desafio_final/Microdados_Educação_Superior_2019/dados/SUP_DOCENTE_2019.csv", header=True, sep='|')

# %%
df_sup_docente.limit(10).toPandas()
# Out:
#   NU_ANO_CENSO CO_IES TP_CATEGORIA_ADMINISTRATIVA TP_ORGANIZACAO_ACADEMICA  \
# 0         2019      1                           1                        1
# 1         2019      1                           1                        1
# 2         2019      1                           1                        1
# 3         2019      1                           1                        1
# 4         2019      1                           1                        1
# 5         2019      1                           1                        1
# 6         2019      1                           1                        1
# 7         2019      1                           1                        1
# 8         2019      1                           1                        1
# 9         2019      1                           1                        1
#
#   CO_DOCENTE_IES                        ID_DOCENTE TP_SITUACAO  \
# 0        1178692  EC5AA8E675AD29C50386820A3F3E9F97           1
# ...

# %%
df_questao_9 = df_sup_docente.filter(col('TP_SEXO') == 1)
df_questao_9.limit(10).toPandas()
# Out:
#   NU_ANO_CENSO CO_IES TP_CATEGORIA_ADMINISTRATIVA TP_ORGANIZACAO_ACADEMICA  \
# 0         2019      1                           1                        1
# 1         2019      1                           1                        1
# 2         2019      1                           1                        1
# 3         2019      1                           1                        1
# 4         2019      1                           1                        1
# 5         2019      1                           1                        1
# 6         2019      1                           1                        1
# 7         2019      1                           1                        1
# 8         2019      1                           1                        1
# 9         2019      1                           1                        1
#
#   CO_DOCENTE_IES                        ID_DOCENTE TP_SITUACAO  \
# 0        1178682  41A74E424F666B113BB386A3BCDECFE1           1
# ...

# %%
(
df_questao_9.groupby("CO_UF_NASCIMENTO")
                    .count()
                    .orderBy(col("count").desc())
                    .limit(20).toPandas()
)
# Out:
#    CO_UF_NASCIMENTO  count
# 0              None  49819
# 1                35  30169
# 2                31  14488
# 3                33  12969
# 4                43  11775
# 5                41  10910
# 6                29   7327
# 7                26   6345
# 8                42   5178
# 9                23   5021
# 10               52   4295
# 11               15   4039
# 12               25   3436
# 13               21   3055
# 14               51   2856
# 15               32   2501
# 16               22   2255
# 17               27   2065
# 18               53   1525
# 19               24   1401

# %%
#10 TP_SEXO = 0 NU_IDADE

# %%
df_questao_10 = df_sup_docente.filter(col('TP_SEXO') == 2)
df_questao_10.limit(10).toPandas()
# Out:
#   NU_ANO_CENSO CO_IES TP_CATEGORIA_ADMINISTRATIVA TP_ORGANIZACAO_ACADEMICA  \
# 0         2019      1                           1                        1
# 1         2019      1                           1                        1
# 2         2019      1                           1                        1
# 3         2019      1                           1                        1
# 4         2019      1                           1                        1
# 5         2019      1                           1                        1
# 6         2019      1                           1                        1
# 7         2019      1                           1                        1
# 8         2019      1                           1                        1
# 9         2019      1                           1                        1
#
#   CO_DOCENTE_IES                        ID_DOCENTE TP_SITUACAO  \
# 0        1178692  EC5AA8E675AD29C50386820A3F3E9F97           1
# ...

# %%
df_questao_10.agg(FUNC.mean('NU_IDADE').alias('mean_NU_IDADE')).show()
# Out:
# +-----------------+
# |    mean_NU_IDADE|
# +-----------------+
# |45.65325425418834|
# +-----------------+

# %%
# 11 TP_SEXO 1 CO_UF_NASCIMENTO OU TP_COR_RACA == 5

# %%
df_questao_11 = df_sup_docente.filter(col("TP_SEXO") == 2)
df_questao_11.limit(10).toPandas()
# Out:
#   NU_ANO_CENSO CO_IES TP_CATEGORIA_ADMINISTRATIVA TP_ORGANIZACAO_ACADEMICA  \
# 0         2019      1                           1                        1
# 1         2019      1                           1                        1
# 2         2019      1                           1                        1
# 3         2019      1                           1                        1
# 4         2019      1                           1                        1
# 5         2019      1                           1                        1
# 6         2019      1                           1                        1
# 7         2019      1                           1                        1
# 8         2019      1                           1                        1
# 9         2019      1                           1                        1
#
#   CO_DOCENTE_IES                        ID_DOCENTE TP_SITUACAO  \
# 0        1178692  EC5AA8E675AD29C50386820A3F3E9F97           1
# ...

# %%
df_questao_10_b =df_questao_10.filter(col('TP_COR_RACA') == 5)

# %%
(
df_questao_10_b.groupby("CO_UF_NASCIMENTO")
                    .count()
                    .orderBy(col("count").desc())
                    .limit(20).toPandas()
)
# Out:
#    CO_UF_NASCIMENTO  count
# 0              None    134
# 1                29     22
# 2                33     20
# 3                15     16
# 4                23     14
# 5                35     14
# 6                43     11
# 7                31      9
# 8                51      7
# 9                42      7
# 10               41      5
# 11               52      5
# 12               32      5
# 13               28      4
# 14               26      4
# 15               27      4
# 16               22      4
# 17               14      4
# 18               53      4
# 19               21      3

# %%
# 12 TP_ESCOLARIDADE 5 e TP_SEXO 1 E 2

# %%
df_questao_12 = df_sup_docente.filter(col('TP_ESCOLARIDADE') == 5)

# %%
(
df_questao_12.groupby("TP_SEXO")
                    .count()
                    .orderBy(col("count").desc())
                    .limit(20).toPandas()
)
# Out:
#   TP_SEXO  count
# 0       2  96703
# 1       1  85551

# %%
#13 NO_CURSO DIREITO

# %%
df_curso_2019 = spark.read.csv("/C:/Users/rodri/Desktop/engenharia de dados/desafio_final/Microdados_Educação_Superior_2019/dados/SUP_CURSO_2019.csv", header=True, sep='|')

# %%
df_curso_2019.limit(10).toPandas()
# Out:
#   NU_ANO_CENSO CO_IES TP_CATEGORIA_ADMINISTRATIVA TP_ORGANIZACAO_ACADEMICA  \
# 0         2019      1                           1                        1
# 1         2019      1                           1                        1
# 2         2019      1                           1                        1
# 3         2019      1                           1                        1
# 4         2019      1                           1                        1
# 5         2019      1                           1                        1
# 6         2019      1                           1                        1
# 7         2019      1                           1                        1
# 8         2019      1                           1                        1
# 9         2019      1                           1                        1
#
#   CO_LOCAL_OFERTA CO_UF CO_MUNICIPIO IN_CAPITAL CO_CURSO  \
# 0          105340    51      5103403          1        1
# ...

# %%
df_questao_13 = df_curso_2019.filter(col('NO_CURSO') == 'DIREITO')
df_questao_13.limit(10).toPandas()
# Out:
#   NU_ANO_CENSO CO_IES TP_CATEGORIA_ADMINISTRATIVA TP_ORGANIZACAO_ACADEMICA  \
# 0         2019      1                           1                        1
# 1         2019      1                           1                        1
# 2         2019      2                           1                        1
# 3         2019      2                           1                        1
# 4         2019      3                           1                        1
# 5         2019      4                           1                        1
# 6         2019      5                           1                        1
# 7         2019      6                           1                        1
# 8         2019      8                           1                        1
# 9         2019      9                           2                        1
#
#   CO_LOCAL_OFERTA CO_UF CO_MUNICIPIO IN_CAPITAL CO_CURSO NO_CURSO  ...  \
# ...

# %%
(
df_questao_13.groupby("CO_UF")
                    .count()
                    .orderBy(col("CO_UF").desc())
                    .limit(30).toPandas()
)
# Out:
#    CO_UF  count
# 0     53     38
# 1     52     71
# 2     51     50
# 3     50     22
# 4     43    104
# 5     42     71
# 6     41    114
# 7     35    288
# 8     33    105
# 9     32     39
# 10    31    201
# 11    29     96
# 12    28     17
# 13    27     22
# 14    26     57
# 15    25     25
# 16    24     23
# 17    23     43
# 18    22     30
# 19    21     36
# 20    17     18
# 21    16      7
# 22    15     37
# 23    14      4
# 24    13     19
# 25    12      8
# 26    11     22
# 27  None      1
