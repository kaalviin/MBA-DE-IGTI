# %% [markdown]
# # TRABALHO PRÁTICO - Spark

# %%
# Primeiro: necessário executar o SPARK via CMD (Anaconda - IGTI) - usar o comando "pyspark"

# %%
# Importa a função para achar o SPARK sendo executado via CONDA
import findspark
findspark.init()

# %%
# Importa a biblioteca para criar a sessão spark
from pyspark.sql import SparkSession

# %%
# Cria a sessão spark para poder trabalhar com os dados
spark = SparkSession.builder.getOrCreate()

# %%
# Mostra a sessão pyspark
print (spark)
# Out:
# <pyspark.sql.session.SparkSession object at 0x0000024A95190C50>

# %% [markdown]
# # INICIANDO O TRABALHO PRÁTICO

# %%
# Importa a biblioteca de manipulação dos DF
from pyspark.sql.types import *
import pyspark.sql.functions as f

# %%
# Cria o Dataframe para a tabela de título dos filmes
df_titles = spark.read.csv('title_basics.tsv', header=True, sep='\t')

# %%
# Cria o Dataframe para a tabela de notas dos filmes
df_ratings = spark.read.csv('title_ratings.tsv', header=True, sep='\t')

# %%
df_titles.show(10)
# Out:
# +---------+---------+--------------------+--------------------+-------+---------+-------+--------------+--------------------+
# |   tconst|titleType|        primaryTitle|       originalTitle|isAdult|startYear|endYear|runtimeMinutes|              genres|
# +---------+---------+--------------------+--------------------+-------+---------+-------+--------------+--------------------+
# |tt0000001|    short|          Carmencita|          Carmencita|      0|     1894|     \N|             1|   Documentary,Short|
# |tt0000002|    short|Le clown et ses c...|Le clown et ses c...|      0|     1892|     \N|             5|     Animation,Short|
# |tt0000003|    short|      Pauvre Pierrot|      Pauvre Pierrot|      0|     1892|     \N|             4|Animation,Comedy,...|
# |tt0000004|    short|         Un bon bock|         Un bon bock|      0|     1892|     \N|            12|     Animation,Short|
# |tt0000005|    short|    Blacksmith Scene|    Blacksmith Scene|      0|     1893|     \N|             1|        Comedy,Short|
# |tt0000006|    short|   Chinese Opium Den|   Chinese Opium Den|      0|     1894|     \N|             1|               Short|
# |tt0000007|    short|Corbett and Court...|Corbett and Court...|      0|     1894|     \N|             1|         Short,Sport|
# |tt0000008|    short|Edison Kinetoscop...|Edison Kinetoscop...|      0|     1894|     \N|             1|   Documentary,Short|
# |tt0000009|    short|          Miss Jerry|          Miss Jerry|      0|     1894|     \N|            40|       Romance,Short|
# |tt0000010|    short| Leaving the Factory|La sortie de l'us...|      0|     1895|     \N|             1|   Documentary,Short|
# +---------+---------+--------------------+--------------------+-------+---------+-------+--------------+--------------------+
# only showing top 10 rows

# %%
df_ratings.show(10)
# Out:
# +---------+-------------+--------+
# |   tconst|averageRating|numVotes|
# +---------+-------------+--------+
# |tt0000001|          5.7|    1809|
# |tt0000002|          6.0|     233|
# |tt0000003|          6.5|    1560|
# |tt0000004|          6.1|     152|
# |tt0000005|          6.2|    2383|
# |tt0000006|          5.1|     157|
# |tt0000007|          5.4|     746|
# |tt0000008|          5.5|    1965|
# |tt0000009|          5.8|     189|
# |tt0000010|          6.9|    6530|
# +---------+-------------+--------+
# only showing top 10 rows

# %%
# QUESTÃO 5
df_titles.filter((f.col('startYear') == '2015') & ((f.col('titleType') == 'movie') | (f.col('titleType') == 'tvMovie'))).count()
# Out:
# 19987

# %%
# QUESTÃO 5 - Outra maneira de responder
(
df_titles
    .filter(f.col('titleType').isin('movie','tvMovie'))
    .filter(f.col('startYear') == '2015')
    .count()
)
# Out:
# 19987

# %%
# QUESTÃO 6
df_titles_subset = (
    df_titles
    .filter('titleType = "movie"')
    .withColumn('genres_array', f.split('genres', ','))
    .withColumn('genres_explode', f.explode(f.col('genres_array')))
    .groupby('genres_explode')
    .count()
    .sort(f.col("count").desc())
    .toPandas()
)
df_titles_subset
# Out:
#    genres_explode   count
# 0           Drama  210839
# 1     Documentary  107661
# 2          Comedy  100023
# 3              \N   70612
# 4          Action   50221
# 5         Romance   43871
# 6        Thriller   39222
# 7           Crime   33810
# 8          Horror   31968
# 9       Adventure   26528
# 10         Family   16051
# 11      Biography   15411
# 12        Mystery   15086
# 13        Fantasy   13725
# 14        History   12893
# 15         Sci-Fi   12414
# 16          Music   11103
# 17        Musical    9673
# 18            War    8784
# 19          Adult    8330
# 20      Animation    7787
# 21        Western    7270
# 22          Sport    6213
# 23           News    1450
# 24      Film-Noir     761
# 25     Reality-TV     423
# 26      Talk-Show     136
# 27          Short      53
# 28      Game-Show      20

# %%
# QUESTÃO 11
(
    df_titles
    .withColumn('n_titles', f.count(f.lit(1)).over(Window.partitionBy('startYear')))
    .withColumn('genres', f.explode(f.split('genres', ',')))
    .filter('startYear = 2018')
    .groupBy('startYear', 'genres', 'n_titles')
    .count()
    .withColumn('percentual', f.col('count')/f.col('n_titles'))
    .toPandas()
)
# Out:
#    startYear       genres  n_titles  count  percentual
# 0       2018        Drama    402244  89367    0.222171
# 1       2018       Comedy    402244  78809    0.195923
# 2       2018           \N    402244  41740    0.103768
# 3       2018  Documentary    402244  37840    0.094072
# 4       2018        Short    402244  66482    0.165278
# 5       2018       Action    402244  15575    0.038720
# 6       2018       Family    402244  16997    0.042255
# 7       2018       Sci-Fi    402244   5644    0.014031
# 8       2018     Thriller    402244   8154    0.020271
# 9       2018      Romance    402244  25002    0.062156
# 10      2018    Adventure    402244  14268    0.035471
# 11      2018    Game-Show    402244  10426    0.025920
# 12      2018        Music    402244  16092    0.040006
# 13      2018    Biography    402244   4080    0.010143
# 14      2018        Crime    402244  15455    0.038422
# 15      2018      Mystery    402244   7523    0.018703
# 16      2018       Horror    402244   9619    0.023913
# 17      2018    Talk-Show    402244  47492    0.118068
# 18      2018        Adult    402244  14749    0.036667
# 19      2018    Animation    402244  17948    0.044620
# 20      2018   Reality-TV    402244  27601    0.068618
# 21      2018        Sport    402244  10332    0.025686
# 22      2018      History    402244   6191    0.015391
# 23      2018         News    402244  25603    0.063650
# 24      2018      Musical    402244   2581    0.006417
# 25      2018      Fantasy    402244   8135    0.020224
# 26      2018          War    402244    760    0.001889
# 27      2018      Western    402244    396    0.000984
